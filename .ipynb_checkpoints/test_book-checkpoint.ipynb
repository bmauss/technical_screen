# %%
# Pandas Test Zone:

# %%
import pandas as pd
df = pd.read_csv('issues.csv')
df.tail(20)
# Out:
#       created_at  number   state  label_bug  label_more_info_needed  \
# 6887  2020-10-16    6888    open      False                   False
# 6888  2020-10-16    6889    open      False                   False
# 6889  2020-10-16    6890    open      False                   False
# 6890  2020-10-16    6891    open      False                   False
# 6891  2020-10-16    6892    open      False                   False
# 6892  2020-10-17    6893    open      False                   False
# 6893  2020-10-17    6894  closed      False                   False
# 6894  2020-10-17    6895    open      False                   False
# 6895  2020-10-17    6896    open      False                   False
# 6896  2020-10-17    6897    open      False                    True
# 6897  2020-10-18    6898    open      False                   False
# 6898  2020-10-18    6899    open      False                    True
# 6899  2020-10-18    6900  closed      False                   False
# ...
